# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
ipl = pd.read_csv("dataset.csv")
ipl.drop(columns="Unnamed: 0",inplace=True)

# %%
ipl
# Out:
#       match_id  runs_after_10_overs  wickets_left  final_score
# 0       335982                   87             9          222
# 1       335983                   88             7          240
# 2       335984                   57             6          129
# 3       335985                   74             8          165
# 4       335988                   45             6          142
# ...        ...                  ...           ...          ...
# 1078   1473506                   83             8          184
# 1079   1473507                  100             9          227
# 1080   1473509                  113             9          228
# 1081   1473510                  102             8          203
# 1082   1473511                   87             8          190
#
# [1083 rows x 4 columns]

# %%
sns.scatterplot(ipl , x="wickets_left" , y="final_score")
# Out:
# <Axes: xlabel='wickets_left', ylabel='final_score'>

# %%
sns.scatterplot(ipl, x ="runs_after_10_overs", y="final_score")
# Out:
# <Axes: xlabel='runs_after_10_overs', ylabel='final_score'>

# %%
ipl.shape
# Out:
# (1083, 4)

# %%
x =ipl.iloc[:,1:3]
y= ipl.iloc[:,3]
x
# Out:
#       runs_after_10_overs  wickets_left
# 0                      87             9
# 1                      88             7
# 2                      57             6
# 3                      74             8
# 4                      45             6
# ...                   ...           ...
# 1078                   83             8
# 1079                  100             9
# 1080                  113             9
# 1081                  102             8
# 1082                   87             8
#
# [1083 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , Y_train,Y_test = train_test_split(x,y ,test_size=0.2 , random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg =LinearRegression()

# %%
reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
reg.coef_
# Out:
# array([1.21655879, 3.81363201])

# %%
from sklearn.metrics import r2_score
r2_score(Y_test , y_pred)
# Out:
# 0.6166491848170982
